# %%
from src.prepare_dataset import load_dataset
import matplotlib.pyplot as plt

images, labels = load_dataset('data/')
plt.figure(figsize=(10, 5))
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(images[i])
    plt.title(labels[i])
    plt.axis('off')
plt.show()

# %%
from src.predict import predict_emotions

predictions = predict_emotions('data/happy/sample.jpg')
print(predictions)
